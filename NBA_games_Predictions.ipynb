# %%
pip install nba_api

# %%
from nba_api.stats.endpoints import leaguegamefinder

# %%
# d'apres la documenttaion , nba id = 00 ( LIEN : https://github.com/swar/nba_api/blob/master/docs/nba_api/stats/library/parameters.md#LeagueID)
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/31/2020' , league_id_nullable='00')
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 0     42022  1610612738               BOS  Boston Celtics  0042200115
# 1     42022  1610612743               DEN  Denver Nuggets  0042200145
# 2     42022  1610612737               ATL   Atlanta Hawks  0042200115
# 3     42022  1610612756               PHX    Phoenix Suns  0042200175
# 4     42022  1610612746               LAC     LA Clippers  0042200175
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2023-04-25  BOS vs. ATL  L  240  117  ...   0.538     9    34   43   31
# 1  2023-04-25  DEN vs. MIN  W  241  112  ...   0.889    16    31   47   22
# 2  2023-04-25    ATL @ BOS  W  242  119  ...   1.000     6    28   34   26
# 3  2023-04-25  PHX vs. LAC  W  240  136  ...   0.875    11    32   43   31
# 4  2023-04-25    LAC @ PHX  L  240  130  ...   0.838    17    29   46   23
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    1    9    9  20        -2.0
# 1   10    3   12  21         3.0
# 2    5    4    8  16         2.0
# 3    7    4    7  27         6.0
# 4    4    1   10  21        -6.0
#
# [5 rows x 28 columns]

# %%
games.shape
# Out:
# (8844, 28)

# %%
games.columns
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %%
games = games[['TEAM_NAME', 'GAME_ID','GAME_DATE', 'MATCHUP', 'WL' ,'PLUS_MINUS' ]]

# %%
games
# Out:
#                    TEAM_NAME     GAME_ID   GAME_DATE      MATCHUP WL  \
# 0             Boston Celtics  0042200115  2023-04-25  BOS vs. ATL  L
# 1             Denver Nuggets  0042200145  2023-04-25  DEN vs. MIN  W
# 2              Atlanta Hawks  0042200115  2023-04-25    ATL @ BOS  W
# 3               Phoenix Suns  0042200175  2023-04-25  PHX vs. LAC  W
# 4                LA Clippers  0042200175  2023-04-25    LAC @ PHX  L
# ...                      ...         ...         ...          ... ..
# 8839            Phoenix Suns  0021900725  2020-01-31  PHX vs. OKC  L
# 8840  Portland Trail Blazers  0021900726  2020-01-31    POR @ LAL  W
# 8841          Denver Nuggets  0021900724  2020-01-31    DEN @ MIL  W
# 8842   Oklahoma City Thunder  0021900725  2020-01-31    OKC @ PHX  W
# 8843           Brooklyn Nets  0021900721  2020-01-31  BKN vs. CHI  W
#
#       PLUS_MINUS
# 0           -2.0
# 1            3.0
# 2            2.0
# 3            6.0
# 4           -6.0
# ...          ...
# 8839        -4.0
# 8840         8.0
# 8841        12.0
# 8842         4.0
# 8843        15.0
#
# [8844 rows x 6 columns]

# %%
# final dataframe ; one row for one game
#                   two columns : 1.result of game :target , 2.score stat comapring two teams: feature

# %%
import pandas as pd
games.info()

# we need to convert the game_date type to date time format
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8844 entries, 0 to 8843
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TEAM_NAME   8844 non-null   object
#  1   GAME_ID     8844 non-null   object
#  2   GAME_DATE   8844 non-null   object
#  3   MATCHUP     8844 non-null   object
#  4   WL          8844 non-null   object
#  5   PLUS_MINUS  8844 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 414.7+ KB

# %%
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

# %%
games.GAME_DATE
# Out:
# 0      2023-04-25
# 1      2023-04-25
# 2      2023-04-25
# 3      2023-04-25
# 4      2023-04-25
#           ...
# 8839   2020-01-31
# 8840   2020-01-31
# 8841   2020-01-31
# 8842   2020-01-31
# 8843   2020-01-31
# Name: GAME_DATE, Length: 8844, dtype: datetime64[ns]

# %%
games = games.sort_values('GAME_DATE')

# %%
games
# Out:
#                TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  PLUS_MINUS
# 8843       Brooklyn Nets  0021900721 2020-01-31  BKN vs. CHI  W        15.0
# 8830       Chicago Bulls  0021900721 2020-01-31    CHI @ BKN  L       -15.0
# 8831  Los Angeles Lakers  0021900726 2020-01-31  LAL vs. POR  L        -8.0
# 8832     Detroit Pistons  0021900720 2020-01-31  DET vs. TOR  L       -13.0
# 8833     Toronto Raptors  0021900720 2020-01-31    TOR @ DET  W        13.0
# ...                  ...         ...        ...          ... ..         ...
# 4            LA Clippers  0042200175 2023-04-25    LAC @ PHX  L        -6.0
# 3           Phoenix Suns  0042200175 2023-04-25  PHX vs. LAC  W         6.0
# 2          Atlanta Hawks  0042200115 2023-04-25    ATL @ BOS  W         2.0
# 1         Denver Nuggets  0042200145 2023-04-25  DEN vs. MIN  W         3.0
# 0         Boston Celtics  0042200115 2023-04-25  BOS vs. ATL  L        -2.0
#
# [8844 rows x 6 columns]

# %%
# calculate for each team the mean of plus minus score for the last 30 game
#closed= 'left' that mean without counting the current game 
games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x:  x.rolling(30 , closed='left').mean())

# %%
# here the first 30 row in the colone avg_30_plus_minus show NAN values because we needthe the avg of the last 30 game , for example for the row number 18 , we have not reach the game 30 to calculate the avg n fior that there is enght data 
games[games['TEAM_NAME']=='Toronto Raptors'].head(35)
# Out:
#             TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  PLUS_MINUS  \
# 8833  Toronto Raptors  0021900720 2020-01-31    TOR @ DET  W        13.0
# 8804  Toronto Raptors  0021900740 2020-02-02  TOR vs. CHI  W        27.0
# 8761  Toronto Raptors  0021900758 2020-02-05  TOR vs. IND  W         1.0
# 8742  Toronto Raptors  0021900772 2020-02-07    TOR @ IND  W         9.0
# 8726  Toronto Raptors  0021900781 2020-02-08  TOR vs. BKN  W         1.0
# 8692  Toronto Raptors  0021900796 2020-02-10  TOR vs. MIN  W        11.0
# 8649  Toronto Raptors  0021900809 2020-02-12    TOR @ BKN  L       -10.0
# 8608  Toronto Raptors  0021900829 2020-02-21  TOR vs. PHX  W        17.0
# 8581  Toronto Raptors  0021900843 2020-02-23  TOR vs. IND  W        46.0
# 8555  Toronto Raptors  0021900858 2020-02-25  TOR vs. MIL  L       -11.0
# 8516  Toronto Raptors  0021900879 2020-02-28  TOR vs. CHA  L        -3.0
# 8479  Toronto Raptors  0021900898 2020-03-01    TOR @ DEN  L       -15.0
# 8454  Toronto Raptors  0021900914 2020-03-03    TOR @ PHX  W         9.0
# 8419  Toronto Raptors  0021900929 2020-03-05    TOR @ GSW  W         8.0
# 8371  Toronto Raptors  0021900956 2020-03-08    TOR @ SAC  W         5.0
# 8361  Toronto Raptors  0021900959 2020-03-09    TOR @ UTA  W         9.0
# 8315  Toronto Raptors  0011900111 2020-07-24  TOR vs. HOU  W        11.0
# 8297  Toronto Raptors  0011900121 2020-07-26  TOR vs. POR  W         6.0
# 8276  Toronto Raptors  0011900129 2020-07-28    TOR @ PHX  L       -11.0
# 8241  Toronto Raptors  0021901243 2020-08-01  TOR vs. LAL  W        15.0
# 8225  Toronto Raptors  0021901250 2020-08-03    TOR @ MIA  W         4.0
# 8193  Toronto Raptors  0021901266 2020-08-05    TOR @ ORL  W        10.0
# 8172  Toronto Raptors  0021901279 2020-08-07  TOR vs. BOS  L       -22.0
# 8157  Toronto Raptors  0021901286 2020-08-09  TOR vs. MEM  W         9.0
# 8136  Toronto Raptors  0021901294 2020-08-10    TOR @ MIL  W         8.0
# 8118  Toronto Raptors  0021901305 2020-08-12    TOR @ PHI  W         4.0
# 8096  Toronto Raptors  0021901318 2020-08-14  TOR vs. DEN  W         8.0
# 8083  Toronto Raptors  0041900111 2020-08-17  TOR vs. BKN  W        24.0
# 8064  Toronto Raptors  0041900112 2020-08-19  TOR vs. BKN  W         5.0
# 8051  Toronto Raptors  0041900113 2020-08-21    TOR @ BKN  W        25.0
# 8036  Toronto Raptors  0041900114 2020-08-23    TOR @ BKN  W        28.0
# 8008  Toronto Raptors  0041900211 2020-08-30  TOR vs. BOS  L       -18.0
# 8001  Toronto Raptors  0041900212 2020-09-01  TOR vs. BOS  L        -3.0
# 7994  Toronto Raptors  0041900213 2020-09-03    TOR @ BOS  W         1.0
# 7987  Toronto Raptors  0041900214 2020-09-05    TOR @ BOS  W         7.0
#
#       avg_30_plus_minus
# 8833                NaN
# 8804                NaN
# 8761                NaN
# 8742                NaN
# 8726                NaN
# 8692                NaN
# 8649                NaN
# 8608                NaN
# 8581                NaN
# 8555                NaN
# 8516                NaN
# 8479                NaN
# 8454                NaN
# 8419                NaN
# 8371                NaN
# 8361                NaN
# 8315                NaN
# 8297                NaN
# 8276                NaN
# 8241                NaN
# 8225                NaN
# 8193                NaN
# 8172                NaN
# 8157                NaN
# 8136                NaN
# 8118                NaN
# 8096                NaN
# 8083                NaN
# 8064                NaN
# 8051                NaN
# 8036           7.100000
# 8008           7.600000
# 8001           6.100000
# 7994           5.966667
# 7987           5.700000

# %%
msk = games['MATCHUP'].str.contains('@')

# %%
games_away = games[msk]
games_home = games[~msk]

# %%
games_away.shape
# Out:
# (4422, 7)

# %%
games_home.shape
# Out:
# (4422, 7)

# %%
games_home
# Out:
#                  TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  PLUS_MINUS  \
# 8843         Brooklyn Nets  0021900721 2020-01-31  BKN vs. CHI  W        15.0
# 8831    Los Angeles Lakers  0021900726 2020-01-31  LAL vs. POR  L        -8.0
# 8832       Detroit Pistons  0021900720 2020-01-31  DET vs. TOR  L       -13.0
# 8835  New Orleans Pelicans  0021900723 2020-01-31  NOP vs. MEM  W        28.0
# 8838       Milwaukee Bucks  0021900724 2020-01-31  MIL vs. DEN  L       -12.0
# ...                    ...         ...        ...          ... ..         ...
# 9               Miami Heat  0042200104 2023-04-24  MIA vs. MIL  W         5.0
# 6       Los Angeles Lakers  0042200154 2023-04-24  LAL vs. MEM  W         6.0
# 3             Phoenix Suns  0042200175 2023-04-25  PHX vs. LAC  W         6.0
# 1           Denver Nuggets  0042200145 2023-04-25  DEN vs. MIN  W         3.0
# 0           Boston Celtics  0042200115 2023-04-25  BOS vs. ATL  L        -2.0
#
#       avg_30_plus_minus
# 8843                NaN
# 8831                NaN
# 8832                NaN
# 8835                NaN
# 8838                NaN
# ...                 ...
# 9             -0.800000
# 6              4.966667
# 3              4.000000
# 1              2.800000
# 0              7.366667
#
# [4422 rows x 7 columns]

# %%
games_away
# Out:
#                    TEAM_NAME     GAME_ID  GAME_DATE    MATCHUP WL  PLUS_MINUS  \
# 8830           Chicago Bulls  0021900721 2020-01-31  CHI @ BKN  L       -15.0
# 8833         Toronto Raptors  0021900720 2020-01-31  TOR @ DET  W        13.0
# 8834       Memphis Grizzlies  0021900723 2020-01-31  MEM @ NOP  L       -28.0
# 8842   Oklahoma City Thunder  0021900725 2020-01-31  OKC @ PHX  W         4.0
# 8837        Dallas Mavericks  0021900722 2020-01-31  DAL @ HOU  L        -7.0
# ...                      ...         ...        ...        ... ..         ...
# 8            Milwaukee Bucks  0042200104 2023-04-24  MIL @ MIA  L        -5.0
# 7          Memphis Grizzlies  0042200154 2023-04-24  MEM @ LAL  L        -6.0
# 5     Minnesota Timberwolves  0042200145 2023-04-25  MIN @ DEN  L        -3.0
# 4                LA Clippers  0042200175 2023-04-25  LAC @ PHX  L        -6.0
# 2              Atlanta Hawks  0042200115 2023-04-25  ATL @ BOS  W         2.0
#
#       avg_30_plus_minus
# 8830                NaN
# 8833                NaN
# 8834                NaN
# 8842                NaN
# 8837                NaN
# ...                 ...
# 8              4.066667
# 7              2.666667
# 5             -1.566667
# 4              0.133333
# 2              0.100000
#
# [4422 rows x 7 columns]

# %%
games_merged = pd.merge(games_home , games_away , on='GAME_ID' , suffixes=('_home' , '_away'))

# %%
games_merged
# Out:
#             TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0            Brooklyn Nets  0021900721     2020-01-31  BKN vs. CHI       W
# 1       Los Angeles Lakers  0021900726     2020-01-31  LAL vs. POR       L
# 2          Detroit Pistons  0021900720     2020-01-31  DET vs. TOR       L
# 3     New Orleans Pelicans  0021900723     2020-01-31  NOP vs. MEM       W
# 4          Milwaukee Bucks  0021900724     2020-01-31  MIL vs. DEN       L
# ...                    ...         ...            ...          ...     ...
# 4417            Miami Heat  0042200104     2023-04-24  MIA vs. MIL       W
# 4418    Los Angeles Lakers  0042200154     2023-04-24  LAL vs. MEM       W
# 4419          Phoenix Suns  0042200175     2023-04-25  PHX vs. LAC       W
# 4420        Denver Nuggets  0042200145     2023-04-25  DEN vs. MIN       W
# 4421        Boston Celtics  0042200115     2023-04-25  BOS vs. ATL       L
#
#       PLUS_MINUS_home  avg_30_plus_minus_home          TEAM_NAME_away  \
# 0                15.0                     NaN           Chicago Bulls
# 1                -8.0                     NaN  Portland Trail Blazers
# 2               -13.0                     NaN         Toronto Raptors
# 3                28.0                     NaN       Memphis Grizzlies
# 4               -12.0                     NaN          Denver Nuggets
# ...               ...                     ...                     ...
# 4417              5.0               -0.800000         Milwaukee Bucks
# 4418              6.0                4.966667       Memphis Grizzlies
# 4419              6.0                4.000000             LA Clippers
# 4420              3.0                2.800000  Minnesota Timberwolves
# 4421             -2.0                7.366667           Atlanta Hawks
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2020-01-31    CHI @ BKN       L            -15.0
# 1        2020-01-31    POR @ LAL       W              8.0
# 2        2020-01-31    TOR @ DET       W             13.0
# 3        2020-01-31    MEM @ NOP       L            -28.0
# 4        2020-01-31    DEN @ MIL       W             12.0
# ...             ...          ...     ...              ...
# 4417     2023-04-24    MIL @ MIA       L             -5.0
# 4418     2023-04-24    MEM @ LAL       L             -6.0
# 4419     2023-04-25    LAC @ PHX       L             -6.0
# 4420     2023-04-25    MIN @ DEN       L             -3.0
# 4421     2023-04-25    ATL @ BOS       W              2.0
#
#       avg_30_plus_minus_away
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 4417                4.066667
# 4418                2.666667
# 4419                0.133333
# 4420               -1.566667
# 4421                0.100000
#
# [4422 rows x 13 columns]

# %%
games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home']-games_merged['avg_30_plus_minus_away']

# %%
games_merged
# Out:
#             TEAM_NAME_home     GAME_ID GAME_DATE_home MATCHUP_home WL_home  \
# 0            Brooklyn Nets  0021900721     2020-01-31  BKN vs. CHI       W
# 1       Los Angeles Lakers  0021900726     2020-01-31  LAL vs. POR       L
# 2          Detroit Pistons  0021900720     2020-01-31  DET vs. TOR       L
# 3     New Orleans Pelicans  0021900723     2020-01-31  NOP vs. MEM       W
# 4          Milwaukee Bucks  0021900724     2020-01-31  MIL vs. DEN       L
# ...                    ...         ...            ...          ...     ...
# 4417            Miami Heat  0042200104     2023-04-24  MIA vs. MIL       W
# 4418    Los Angeles Lakers  0042200154     2023-04-24  LAL vs. MEM       W
# 4419          Phoenix Suns  0042200175     2023-04-25  PHX vs. LAC       W
# 4420        Denver Nuggets  0042200145     2023-04-25  DEN vs. MIN       W
# 4421        Boston Celtics  0042200115     2023-04-25  BOS vs. ATL       L
#
#       PLUS_MINUS_home  avg_30_plus_minus_home          TEAM_NAME_away  \
# 0                15.0                     NaN           Chicago Bulls
# 1                -8.0                     NaN  Portland Trail Blazers
# 2               -13.0                     NaN         Toronto Raptors
# 3                28.0                     NaN       Memphis Grizzlies
# 4               -12.0                     NaN          Denver Nuggets
# ...               ...                     ...                     ...
# 4417              5.0               -0.800000         Milwaukee Bucks
# 4418              6.0                4.966667       Memphis Grizzlies
# 4419              6.0                4.000000             LA Clippers
# 4420              3.0                2.800000  Minnesota Timberwolves
# 4421             -2.0                7.366667           Atlanta Hawks
#
#      GAME_DATE_away MATCHUP_away WL_away  PLUS_MINUS_away  \
# 0        2020-01-31    CHI @ BKN       L            -15.0
# 1        2020-01-31    POR @ LAL       W              8.0
# 2        2020-01-31    TOR @ DET       W             13.0
# 3        2020-01-31    MEM @ NOP       L            -28.0
# 4        2020-01-31    DEN @ MIL       W             12.0
# ...             ...          ...     ...              ...
# 4417     2023-04-24    MIL @ MIA       L             -5.0
# 4418     2023-04-24    MEM @ LAL       L             -6.0
# 4419     2023-04-25    LAC @ PHX       L             -6.0
# 4420     2023-04-25    MIN @ DEN       L             -3.0
# 4421     2023-04-25    ATL @ BOS       W              2.0
#
#       avg_30_plus_minus_away  avg_30_plus_minus_diff
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 4417                4.066667               -4.866667
# 4418                2.666667                2.300000
# 4419                0.133333                3.866667
# 4420               -1.566667                4.366667
# 4421                0.100000                7.266667
#
# [4422 rows x 14 columns]

# %%
games_model = games_merged[['WL_home' , 'avg_30_plus_minus_diff']].dropna()

# %%
games_model
# Out:
#      WL_home  avg_30_plus_minus_diff
# 398        W                1.933333
# 400        L               -6.233333
# 401        L               -5.366667
# 402        L               -5.600000
# 403        W               -4.333333
# ...      ...                     ...
# 4417       W               -4.866667
# 4418       W                2.300000
# 4419       W                3.866667
# 4420       W                4.366667
# 4421       L                7.266667
#
# [3904 rows x 2 columns]

# %%
games_model['WL_home'] = games_model['WL_home'].map({'W':1 , 'L':0})

# %%
games_model
# Out:
#       WL_home  avg_30_plus_minus_diff
# 398         1                1.933333
# 400         0               -6.233333
# 401         0               -5.366667
# 402         0               -5.600000
# 403         1               -4.333333
# ...       ...                     ...
# 4417        1               -4.866667
# 4418        1                2.300000
# 4419        1                3.866667
# 4420        1                4.366667
# 4421        0                7.266667
#
# [3904 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
df_train , df_test = train_test_split(games_model , stratify=games_model['WL_home'] , test_size=0.3 , random_state=7)

# %%
df_train.shape
# Out:
# (2732, 2)

# %%
df_test.shape
# Out:
# (1172, 2)

# %%
target = 'WL_home'

x_train  =df_train.drop(columns=target)
y_train = df_train[target]

x_test  =df_train.drop(columns=target)
y_test = df_train[target]

# %%
# we focsed on XDBoost to show the general steps of modeling
# XGBoost is a popular gradiant boosting libarie

# %%
import xgboost as xgb

# %%
clf = xgb.XGBClassifier(random_state=7)
clf.fit(x_train , y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=7,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
from sklearn.metrics import accuracy_score
y_pred = clf.predict(x_test)

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.7141288433382138

# %% [markdown]
# triying to improve the model

# %%
#RandomizedSearchCV is a randomized search over a hyperparameter space,
# which means that it randomly selects hyperparameters from a specified
# distribution to evaluate the performance of the model. 
#It then uses cross-validation to evaluate the performance of the model
# on different subsets of the data, and returns the best hyperparameters
# that result in the best cross-validation performance.

# %%
# hyperparameter : it is  a parameters with values was set before the learning process begins
# hyperparameter tuning - approch : ranndom search 
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils.fixes import loguniform

# %%
hyp_params = {'learning_rate' : loguniform(0.0001 ,1), 
              'max_depth' :[1,2,3,4,5,6,7,8,9],
              'subsample' : [0.5,0.6,0.7,0.8,0.9,1.0],
              'n_estimators' : [25,50,75,100,125,150,200]}

# %%
random_hyp = RandomizedSearchCV(estimator=clf,
                                param_distributions=hyp_params,
                                n_iter = 15,
                                cv=7,
                                scoring='accuracy',
                                random_state=7)

# %%
random_hyp.fit(x_train , y_train)
# Out:
# RandomizedSearchCV(cv=7,
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            callbacks=None, colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, gamma=0, gpu_id=-1,
#                                            grow_policy='depthwise',
#                                            importance_type=None,
#                                            interaction_constraints='',
#                                            learning_rate=0.300000012,
#                                            max_bin=256,...
#                                            num_parallel_tree=1,
#                                            predictor='auto', random_state=7,
#                                            reg_alpha=0, reg_lambda=1, ...),
#                    n_iter=15,
#                    param_distributions={'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x0000017EE496D6C0>,
#                                         'max_depth': [1, 2, 3, 4, 5, 6, 7, 8,
#                                                       9],
#                                         'n_estimators': [25, 50, 75, 100, 125,
#                                                          150, 200],
#                                         'subsample': [0.5, 0.6, 0.7, 0.8, 0.9,
#                                                       1.0]},
#                    random_state=7, scoring='accuracy')

# %%
random_hyp.best_params_
# Out:
# {'learning_rate': 0.0017411531294131313,
#  'max_depth': 2,
#  'n_estimators': 100,
#  'subsample': 0.8}

# %%
model_hyp = random_hyp.best_estimator_

# %%
y_pred_hyp = model_hyp.predict(x_test)

# %%
accuracy_score(y_test , y_pred_hyp)
# Out:
# 0.6357979502196194

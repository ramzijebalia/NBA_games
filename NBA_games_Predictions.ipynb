# %%
pip install nba_api

# %%
from nba_api.stats.endpoints import leaguegamefinder

# %%
# d'apres la documenttaion , nba id = 00 ( LIEN : https://github.com/swar/nba_api/blob/master/docs/nba_api/stats/library/parameters.md#LeagueID)
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/31/2020' , league_id_nullable='00')
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME     GAME_ID  \
# 0     42022  1610612737               ATL           Atlanta Hawks  0042200114
# 1     42022  1610612758               SAC        Sacramento Kings  0042200164
# 2     42022  1610612738               BOS          Boston Celtics  0042200114
# 3     42022  1610612750               MIN  Minnesota Timberwolves  0042200144
# 4     42022  1610612744               GSW   Golden State Warriors  0042200164
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2023-04-23  ATL vs. BOS  L  240  121  ...   0.875    11    31   42   25
# 1  2023-04-23    SAC @ GSW  L  240  125  ...   0.833    12    32   44   25
# 2  2023-04-23    BOS @ ATL  W  240  129  ...   0.840     9    40   49   25
# 3  2023-04-23  MIN vs. DEN  W  265  114  ...   0.773    14    37   51   23
# 4  2023-04-23  GSW vs. SAC  W  240  126  ...   0.917     8    36   44   31
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    8    4   12  24        -8.0
# 1    5    3   10  21        -1.0
# 2    4    5   16  23         8.0
# 3    6    7   11  19         6.0
# 4    8    6   11  19         1.0
#
# [5 rows x 28 columns]

# %%
games.shape
# Out:
# (8834, 28)
